# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !wget -P /content/drive/MyDrive/SemantiCAM http://128.32.162.150/bdd100k/bdd100k_seg_maps.zip
# !unzip -q /content/drive/MyDrive/SemantiCAM/bdd100k_seg_maps.zip -d /content/drive/MyDrive/SemantiCAM/bdd100k_seg_maps

# %%
# !wget -P /content/drive/MyDrive/SemantiCAM http://128.32.162.150/bdd100k/bdd100k_images_10k.zip
# !unzip -q /content/drive/MyDrive/SemantiCAM/bdd100k_images_10k.zip -d /content/drive/MyDrive/SemantiCAM/bdd100k_images_10k
