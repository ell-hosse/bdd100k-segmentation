# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ell-hosse/bdd100k-segmentation
# %cd bdd100k-segmentation
# Out:
# Cloning into 'bdd100k-segmentation'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
# /content/bdd100k-segmentation

# %%
# %matplotlib inline

# %run visualize_samples.py \
    --images_dir "/content/drive/MyDrive/SemantiCAM/bdd100k_images_10k/10k/train" \
    --masks_dir  "/content/drive/MyDrive/SemantiCAM/bdd100k_seg_maps/color_labels/train" \
    --num_samples 10
